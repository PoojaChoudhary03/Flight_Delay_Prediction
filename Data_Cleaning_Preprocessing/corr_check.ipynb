# %%
import pandas as pd

# %%
dfm = pd.read_csv('dfm.csv')

# %%
# drop some irrelevant columns
dfm = dfm.drop(["Unnamed: 0.1"], axis = 1)

# %%
dfm.corr()
# Out:
#                      CRS_DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  \
# CRS_DEP_TIME             1.000000   0.044224 -0.098748    0.717495   0.248816
# DEP_DELAY                0.044224   1.000000 -0.141674    0.035823  -0.059938
# TAXI_OUT                -0.098748  -0.141674  1.000000   -0.051495  -0.012355
# WHEELS_OFF               0.717495   0.035823 -0.051495    1.000000   0.473089
# WHEELS_ON                0.248816  -0.059938 -0.012355    0.473089   1.000000
# TAXI_IN                 -0.060541  -0.069899 -0.011407   -0.043965   0.030974
# CRS_ARR_TIME             0.568622   0.036867 -0.046190    0.631790   0.627110
# ARR_DELAY                0.013024   0.970145  0.024661    0.011813  -0.062722
# CRS_ELAPSED_TIME        -0.050316  -0.012559  0.057961   -0.067147  -0.028386
# ACTUAL_ELAPSED_TIME     -0.083183  -0.083806  0.238201   -0.091325  -0.027762
# AIR_TIME                -0.057515  -0.047409  0.027921   -0.078681  -0.030240
# DISTANCE                -0.043178  -0.021619  0.011693   -0.074269  -0.041310
# WEATHER_DELAY            0.003858   0.311446  0.034464   -0.021509  -0.026537
# DAY                      0.001484  -0.006863 -0.014636   -0.001279  -0.004379
# MONTH                    0.008217  -0.008886 -0.006978   -0.000728  -0.000248
#
#                       TAXI_IN  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# CRS_DEP_TIME        -0.060541      0.568622   0.013024         -0.050316
# DEP_DELAY           -0.069899      0.036867   0.970145         -0.012559
# TAXI_OUT            -0.011407     -0.046190   0.024661          0.057961
# WHEELS_OFF          -0.043965      0.631790   0.011813         -0.067147
# WHEELS_ON            0.030974      0.627110  -0.062722         -0.028386
# TAXI_IN              1.000000     -0.006637   0.023541          0.098647
# CRS_ARR_TIME        -0.006637      1.000000   0.020924         -0.008528
# ARR_DELAY            0.023541      0.020924   1.000000         -0.008022
# CRS_ELAPSED_TIME     0.098647     -0.008528  -0.008022          1.000000
# ACTUAL_ELAPSED_TIME  0.196726     -0.026598  -0.014787          0.963496
# AIR_TIME             0.082744     -0.016732  -0.023966          0.984396
# DISTANCE             0.072338     -0.017189  -0.018155          0.982411
# WEATHER_DELAY       -0.003799      0.004898   0.325205         -0.012720
# DAY                 -0.006601     -0.003799  -0.010447         -0.002943
# MONTH                0.018318      0.008644  -0.003249          0.008346
#
#                      ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  WEATHER_DELAY  \
# CRS_DEP_TIME                   -0.083183 -0.057515 -0.043178       0.003858
# DEP_DELAY                      -0.083806 -0.047409 -0.021619       0.311446
# TAXI_OUT                        0.238201  0.027921  0.011693       0.034464
# WHEELS_OFF                     -0.091325 -0.078681 -0.074269      -0.021509
# WHEELS_ON                      -0.027762 -0.030240 -0.041310      -0.026537
# TAXI_IN                         0.196726  0.082744  0.072338      -0.003799
# CRS_ARR_TIME                   -0.026598 -0.016732 -0.017189       0.004898
# ARR_DELAY                      -0.014787 -0.023966 -0.018155       0.325205
# CRS_ELAPSED_TIME                0.963496  0.984396  0.982411      -0.012720
# ACTUAL_ELAPSED_TIME             1.000000  0.970077  0.945884      -0.009989
# AIR_TIME                        0.970077  1.000000  0.979577      -0.017681
# DISTANCE                        0.945884  0.979577  1.000000      -0.017517
# WEATHER_DELAY                  -0.009989 -0.017681 -0.017517       1.000000
# DAY                            -0.006366 -0.002574  0.000351      -0.006632
# MONTH                           0.014353  0.014291  0.018526      -0.005530
#
#                           DAY     MONTH
# CRS_DEP_TIME         0.001484  0.008217
# DEP_DELAY           -0.006863 -0.008886
# TAXI_OUT            -0.014636 -0.006978
# WHEELS_OFF          -0.001279 -0.000728
# WHEELS_ON           -0.004379 -0.000248
# TAXI_IN             -0.006601  0.018318
# CRS_ARR_TIME        -0.003799  0.008644
# ARR_DELAY           -0.010447 -0.003249
# CRS_ELAPSED_TIME    -0.002943  0.008346
# ACTUAL_ELAPSED_TIME -0.006366  0.014353
# AIR_TIME            -0.002574  0.014291
# DISTANCE             0.000351  0.018526
# WEATHER_DELAY       -0.006632 -0.005530
# DAY                  1.000000  0.065284
# MONTH                0.065284  1.000000

# %%
abs(dfm.corr())>.75
# Out:
#                      CRS_DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  \
# CRS_DEP_TIME                 True      False     False       False      False
# DEP_DELAY                   False       True     False       False      False
# TAXI_OUT                    False      False      True       False      False
# WHEELS_OFF                  False      False     False        True      False
# WHEELS_ON                   False      False     False       False       True
# TAXI_IN                     False      False     False       False      False
# CRS_ARR_TIME                False      False     False       False      False
# ARR_DELAY                   False       True     False       False      False
# CRS_ELAPSED_TIME            False      False     False       False      False
# ACTUAL_ELAPSED_TIME         False      False     False       False      False
# AIR_TIME                    False      False     False       False      False
# DISTANCE                    False      False     False       False      False
# WEATHER_DELAY               False      False     False       False      False
# DAY                         False      False     False       False      False
# MONTH                       False      False     False       False      False
#
#                      TAXI_IN  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# CRS_DEP_TIME           False         False      False             False
# DEP_DELAY              False         False       True             False
# TAXI_OUT               False         False      False             False
# WHEELS_OFF             False         False      False             False
# WHEELS_ON              False         False      False             False
# TAXI_IN                 True         False      False             False
# CRS_ARR_TIME           False          True      False             False
# ARR_DELAY              False         False       True             False
# CRS_ELAPSED_TIME       False         False      False              True
# ACTUAL_ELAPSED_TIME    False         False      False              True
# AIR_TIME               False         False      False              True
# DISTANCE               False         False      False              True
# WEATHER_DELAY          False         False      False             False
# DAY                    False         False      False             False
# MONTH                  False         False      False             False
#
#                      ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  WEATHER_DELAY  \
# CRS_DEP_TIME                       False     False     False          False
# DEP_DELAY                          False     False     False          False
# TAXI_OUT                           False     False     False          False
# WHEELS_OFF                         False     False     False          False
# WHEELS_ON                          False     False     False          False
# TAXI_IN                            False     False     False          False
# CRS_ARR_TIME                       False     False     False          False
# ARR_DELAY                          False     False     False          False
# CRS_ELAPSED_TIME                    True      True      True          False
# ACTUAL_ELAPSED_TIME                 True      True      True          False
# AIR_TIME                            True      True      True          False
# DISTANCE                            True      True      True          False
# WEATHER_DELAY                      False     False     False           True
# DAY                                False     False     False          False
# MONTH                              False     False     False          False
#
#                        DAY  MONTH
# CRS_DEP_TIME         False  False
# DEP_DELAY            False  False
# TAXI_OUT             False  False
# WHEELS_OFF           False  False
# WHEELS_ON            False  False
# TAXI_IN              False  False
# CRS_ARR_TIME         False  False
# ARR_DELAY            False  False
# CRS_ELAPSED_TIME     False  False
# ACTUAL_ELAPSED_TIME  False  False
# AIR_TIME             False  False
# DISTANCE             False  False
# WEATHER_DELAY        False  False
# DAY                   True  False
# MONTH                False   True

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

pd.set_option('display.max_columns', None)
import datetime, warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(20,14))
ax = sns.heatmap(dfm.corr(), cmap='viridis', center=0, annot=True)
bottom, top = ax.get_ylim()
plt.text(0,-0.6, "df2 - Heat Map", fontsize = 30, color='Black', fontstyle='normal')
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.yticks(rotation=0, fontsize=14)
plt.xticks(rotation=90, fontsize=14)
plt.show()

# %%
#The missing features are the categorical ones so I will deal with those directly in the Modeling notebook. 
#Here what I am going to do is reduce the possibility if collinearity.

# %%
dfm.hist(figsize  = [15, 15],bins=12) 
plt.show()

# %%
dfm_jan = dfm[(dfm['MONTH'] == 1)]
dfm_jan.head()
# Out:
#       FL_DATE       OP_CARRIER     ORIGIN         DEST  CRS_DEP_TIME  \
# 0  2018-01-01  United Airlines    Chicago    Cleveland             4
# 1  2018-01-01  United Airlines    Chicago   Burlington             4
# 2  2018-01-01  United Airlines    Orlando  Los Angeles             2
# 3  2018-01-01  United Airlines     Newark   Sacramento             4
# 4  2018-01-01  United Airlines  Ft. Myers       Newark             3
#
#    DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  CRS_ARR_TIME  \
# 0      121.0      24.0           4          1      8.0             4
# 1       76.0      14.0           4          1      5.0             1
# 2       54.0      14.0           2          2     22.0             2
# 3       72.0      16.0           4          4      4.0             4
# 4       47.0      12.0           3          3      6.0             3
#
#    ARR_DELAY  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0      129.0              72.0                 80.0      48.0     316.0
# 1       73.0             121.0                118.0      99.0     763.0
# 2       55.0             337.0                338.0     302.0    2218.0
# 3       25.0             386.0                339.0     319.0    2500.0
# 4       29.0             167.0                149.0     131.0    1068.0
#
#    WEATHER_DELAY  DAY  MONTH MONTH_AB
# 0            0.0    1      1      Jan
# 1           11.0    1      1      Jan
# 2            0.0    1      1      Jan
# 3            0.0    1      1      Jan
# 4            0.0    1      1      Jan

# %%
dfm_jan.MONTH.value_counts()
# Out:
# 1    97639
# Name: MONTH, dtype: int64

# %%
sns.set_style('darkgrid')

fig = plt.figure(1, figsize=(15,9))
ax = sns.barplot(x="DAY", y="DEP_DELAY", data=dfm_jan, palette="Blues")
plt.title('January ', fontsize=18)
plt.xlabel('Number of Destinations', fontsize=14, labelpad=10);
plt.show()

# %%
dfm.shape
# Out:
# (1351282, 20)
